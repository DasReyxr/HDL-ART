# %% [markdown]
# # Cal

# %%
import math
import numpy as np

# %%
def deg2rad(deg):
    return deg * (math.pi / 180)

DEG = 80
theta = int(deg2rad(DEG)*2**(15))
theta_hex = hex(theta & 0x1FFFF)  # Mask to 17 bits
print(theta)
np.sin(np.deg2rad(DEG))
# Out:
# 45752
# np.float64(0.984807753012208)

# %%
sine_hex = 0x7E0C  # Placeholder for sine value in hex
sine = int(sine_hex)*2**(-15)  # Convert back to float from Q2.15 format
sine
# Out:
# 0.9847412109375

# %%
# Out:
# np.float64(0.984807753012208)
